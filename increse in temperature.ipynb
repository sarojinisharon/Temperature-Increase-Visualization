# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Febin\Downloads\new\temp.csv")

print(type(data))
u
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.DataFrame(data, columns = ['YEAR', 'ANNUAL',  
                                    'JAN-FEB', 'MAR-MAY', 
                                    'JUN-SEP', 'OCT-DEC'] ) 
df.hist()
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a379b91757f9> in <module>()
#       3                                     'JUN-SEP', 'OCT-DEC'] )
#       4 df.hist()
# ----> 5 plot.show()
#
# NameError: name 'plot' is not defined

# %%
#BAE CHART
df.plot.bar()
plt.bar(df['JAN-FEB'], df['MAR-MAY'],df['JUN-SEP'],df['OCT-DEC']) 
plt.xlabel("JAN-FEB") 
plt.ylabel("OCT-DEC") 
plt.show()

# %%
#BOX CHART
df.plot.box() 
plt.boxplot(df['JUN-SEP']) 
plt.show()

# %%
#PIE CHART
plt.pie(df['JAN-FEB'], labels = {"A", "B", "C", 
                             "D", "E", "F", 
                             "G", "H", "I", "J"}, 
                               
autopct ='% 1.1f %%', shadow = True) 
plt.show() 
  
plt.pie(df['MAR-MAY'], labels = {"A", "B", "C", 
                             "D", "E", "F", 
                             "G", "H", "I", "J"}, 
                                  
autopct ='% 1.1f %%', shadow = True) 
plt.show() 
  
plt.pie(df['JUN-SEP'], labels = {"A", "B", "C", 
                             "D", "E", "F", 
                             "G", "H", "I", "J" }, 
autopct ='% 1.1f %%', shadow = True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-26f0b0bf448b> in <module>()
#       1 plt.pie(df['JAN-FEB'], labels = {"X","Y"},
#       2
# ----> 3 autopct ='% 1.1f %%', shadow = True)
#       4 plt.show()
#       5
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, hold, data)
#    3341                      radius=radius, counterclock=counterclock,
#    3342                      wedgeprops=wedgeprops, textprops=textprops, center=center,
# -> 3343                      frame=frame, rotatelabels=rotatelabels, data=data)
#    3344     finally:
#    3345         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
#scatter plot
plt.scatter(df['JAN-FEB'], df['MAR-MAY']) 
plt.show() 
  
# scatter plot between jan-feb jun-sep 
plt.scatter(df['JAN-FEB'], df['JUN-SEP']) 
plt.show() 

# scatter plot between jun-sep mar-may
plt.scatter(df['JUN-SEP'], df['MAR-MAY']) 
plt.show() 
  
# scatter plot between mar_may
plt.scatter(df['MAR-MAY'], df['OCT-DEC']) 
plt.show()
